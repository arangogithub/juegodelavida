# %%
import juegodelavida4 as jv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
init = np.zeros((20,20))
init[5,1] = 1
init[5,2] = 1
init[5,3] = 1
init[5,4] = 1
init[5,5] = 1
init[5,7] = 1
init[5,8] = 1
init[5,9] = 1
init[5,10] = 1
init[5,11] = 1

# %%
ev = jv.evolucion(25, init) 
jv.muestre(ev[1])

# %%
jv.muestre2(ev[0],ev[1])

# %%
type(jv2)
# Out:
# NoneType

# %%
jv.muestre3(ev[0],ev[1], ev[2])

# %%
jv.muestre4(ev[0],ev[1], ev[2], ev[3])

# %%
jv.muestre4(ev[4],ev[5], ev[6], ev[7])

# %%
jv.muestre4(ev[8],ev[9], ev[10], ev[11])

# %%
jv.muestre4(ev[12],ev[13], ev[14], ev[15])

# %%
jv.muestre4(ev[16],ev[17], ev[18], ev[19])

# %%
jv.muestre4(ev[20],ev[21], ev[22], ev[23])
